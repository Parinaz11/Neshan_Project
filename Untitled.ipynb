# %%
import pandas as pd
import networkx as nx

dataset = pd.read_csv('dataset.csv')
dataset
# Out:
#         edge_id  length  minute      speed  is_holiday  weather
# 0           246    1726     505  22.140185           1        1
# 1           316    1750     740  54.303369           0        0
# 2           387    1612     745  56.303877           0        1
# 3           303    1927    1335  23.641228           0        2
# 4           250    1901     915  41.503161           0        1
# ...         ...     ...     ...        ...         ...      ...
# 784219      221    1851    1015  27.068770           0        1
# 784220      227    1768     175  47.168667           0        1
# 784221      110    1699    1220  28.605635           0        1
# 784222      289    1750    1410  21.889339           0        1
# 784223       83    1903     775  46.995337           0        1
#
# [784224 rows x 6 columns]

# %%
testCases = pd.read_csv('test_cases.csv')
testCases
# Out:
#       src  dest  route_start_t  is_holiday  weather  eta  route
# 0      27    90            521           0        0  NaN    NaN
# 1      60   114            835           1        2  NaN    NaN
# 2      18   112            668           0        0  NaN    NaN
# 3      96    18           1114           0        2  NaN    NaN
# 4      66   135           1116           0        0  NaN    NaN
# ...   ...   ...            ...         ...      ...  ...    ...
# 9995   82   194            605           0        0  NaN    NaN
# 9996   75   159            497           0        1  NaN    NaN
# 9997   14   176            712           0        0  NaN    NaN
# 9998   14    77           1136           0        0  NaN    NaN
# 9999   22    59           1105           0        0  NaN    NaN
#
# [10000 rows x 7 columns]

# %%
pickle = pd.read_pickle('network.gpickle')
pickle

# %%
my_graph = nx.read_gpickle('network.gpickle')
nx.draw(my_graph, with_labels=True)

# %%
nx.read_adjlist(my_graph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 nx.read_adjlist(my_graph)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\utils\decorators.py:845, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     844 def func(*args, __wrapper=None, **kwargs):
# --> 845     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 18:5, in argmap_read_adjlist_14(path, comments, delimiter, create_using, nodetype, encoding)
#       3 import gzip
#       4 import inspect
# ----> 5 import itertools
#       6 import re
#       7 from collections import defaultdict
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\readwrite\adjlist.py:289, in read_adjlist(path, comments, delimiter, create_using, nodetype, encoding)
#     221 """Read graph in adjacency list format from path.
#     222
#     223 Parameters
#    (...)
#     286 write_adjlist
#     287 """
#     288 lines = (line.decode(encoding) for line in path)
# --> 289 return parse_adjlist(
#     290     lines,
#     291     comments=comments,
#     292     delimiter=delimiter,
#     293     create_using=create_using,
#     294     nodetype=nodetype,
#     295 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\readwrite\adjlist.py:184, in parse_adjlist(lines, comments, delimiter, create_using, nodetype)
#     143 """Parse lines of a graph adjacency list representation.
#     144
#     145 Parameters
#    (...)
#     181
#     182 """
#     183 G = nx.empty_graph(0, create_using)
# --> 184 for line in lines:
#     185     p = line.find(comments)
#     186     if p >= 0:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\networkx\readwrite\adjlist.py:288, in <genexpr>(.0)
#     212 @open_file(0, mode="rb")
#     213 def read_adjlist(
#     214     path,
#    (...)
#     219     encoding="utf-8",
#     220 ):
#     221     """Read graph in adjacency list format from path.
#     222
#     223     Parameters
#    (...)
#     286     write_adjlist
#     287     """
# --> 288     lines = (line.decode(encoding) for line in path)
#     289     return parse_adjlist(
#     290         lines,
#     291         comments=comments,
#    (...)
#     294         nodetype=nodetype,
#     295     )
#
# AttributeError: 'int' object has no attribute 'decode'

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def histplot(name):
    plt.figure(figsize=(8,5))
    sns.histplot(dataset[name], color='cadetblue')
    plt.title(name, fontsize=16, fontweight='bold')
    plt.xlabel(name, fontsize=12)
    plt.show()
    
barplot('speed')

# %%
mean = dataset.speed.mean()
std = dataset.speed.std()
z = dataset.speed.apply(lambda x: abs(x-mean)/std)
z.describe()
# Out:
# count    7.685400e+05
# mean     7.777547e-01
# std      6.285673e-01
# min      4.227640e-09
# 25%      2.834032e-01
# 50%      6.205994e-01
# 75%      1.143641e+00
# max      7.397472e+00
# Name: speed, dtype: float64

# %%
dataset(z[z>3].index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 dataset(z[z>3].index)
#
# TypeError: 'DataFrame' object is not callable

# %%
dataset.drop(z[z>3].index, inplace=True)
dataset
# Out:
#         edge_id  length  minute      speed  is_holiday  weather
# 0           246    1726     505  22.140185           1        1
# 1           316    1750     740  54.303369           0        0
# 2           387    1612     745  56.303877           0        1
# 3           303    1927    1335  23.641228           0        2
# 4           250    1901     915  41.503161           0        1
# ...         ...     ...     ...        ...         ...      ...
# 784219      221    1851    1015  27.068770           0        1
# 784220      227    1768     175  47.168667           0        1
# 784221      110    1699    1220  28.605635           0        1
# 784222      289    1750    1410  21.889339           0        1
# 784223       83    1903     775  46.995337           0        1
#
# [780222 rows x 6 columns]

# %%
505/60
# Out:
# 8.416666666666666

# %%
def scatterPlot(name, name2):
    plt.figure(figsize=(8,5))
    plt.scatter(dataset[name], dataset[name2], s=3, c='darksalmon')
    plt.title(name + ' Vs ' + name2, fontweight='bold')
    plt.xlabel(name, fontsize=13)
    plt.ylabel(name2, fontsize=13)
    plt.show()
    
scatterPlot('edge_id', 'speed')

# %%
a = dataset.groupby('edge_id')
a.head()
dataset[dataset.edge_id = 256]
# Out:
#   Input In [24]
#     dataset[dataset.edge_id = 256]
#             ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?
